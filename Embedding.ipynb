# %%
import sqlite3
import pandas as pd
import random

# %%
df = pd.read_csv('chunked_data.csv')

# %%
df.shape
# Out:
# (71994, 3)

# %%
! pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (2.7.0)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.40.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.2.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.13.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.11.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (24.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
sampled_df = df.sample(frac=0.05)
sampled_df = sampled_df.reset_index(drop=True)

# %%
# Encode the chunk text to get semantic embeddings
chunk_embeddings = model.encode(sampled_df['chunk_text'].tolist())

# Add the embeddings to the DataFrame
sampled_df['embeddings'] = chunk_embeddings.tolist()

# %%
sampled_df.head()
# Out:
#                                                 name  chunk_index  \
# 0  the.repair.shop.s08.e05.painting.of.queen.henr...            4
# 1  diagnosis.murder.s07.e15.jakes.women.(2000).en...            6
# 2     jehanabad.of.love.war.s01.e08.milan.().eng.1cd            1
# 3     teen.wolf.s05.e03.dreamcatchers.(2015).eng.1cd            1
# 4  welcome.to.eden.s02.e02.episode.2.2.(2023).eng...            2
#
#                                           chunk_text  \
# 0  fit bent lever yellow submarine popup hatch me...
# 1  yeah hard live uh uh france wanted call say hi...
# 2  lift lift happened sonu happened happen munawa...
# 3  think dont know yet previously teen wolf cant ...
# 4  come oh cant excuse havent finished match yet ...
#
#                                           embeddings
# 0  [-0.059462856501340866, -0.07083207368850708, ...
# 1  [-0.09489841014146805, -0.0891512930393219, 0....
# 2  [-0.07662401348352432, -0.002949650166556239, ...
# 3  [-0.04792579263448715, -0.11751582473516464, 0...
# 4  [-0.07520384341478348, -0.0391005203127861, 0....

# %%
sampled_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3600 entries, 0 to 3599
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         3600 non-null   object
#  1   chunk_index  3600 non-null   int64
#  2   chunk_text   3600 non-null   object
#  3   embeddings   3600 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 112.6+ KB

# %%
# !pip install chromadb
# Out:
# Requirement already satisfied: chromadb in /usr/local/lib/python3.10/dist-packages (0.4.24)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.2.1)
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.10/dist-packages (from chromadb) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb) (2.7.0)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.110.2)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.29.0)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.25.2)
# Requirement already satisfied: posthog>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.11.0)
# Requirement already satisfied: pulsar-client>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (3.5.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.17.3)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.24.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.66.2)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.10/dist-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.62.2)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.1.2)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.9.4)
# Requirement already satisfied: kubernetes>=28.1.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (29.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (8.2.3)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.10/dist-packages (from chromadb) (3.10.1)
# Requirement already satisfied: packaging>=19.1 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (24.0)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (1.0.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (2.0.1)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb) (0.37.2)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2024.2.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.7.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.0.7)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<=7.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.63.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.24.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-proto==1.24.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.45b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.45b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.45b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-util-http==0.45b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (67.7.2)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-asgi==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb) (2.18.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb) (3.7)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.13.2->chromadb) (0.20.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (12.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2023.6.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.18.1)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette<0.38.0,>=0.37.2->fastapi>=0.95.2->chromadb) (3.7.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.38.0,>=0.37.2->fastapi>=0.95.2->chromadb) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.38.0,>=0.37.2->fastapi>=0.95.2->chromadb) (1.2.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.0)

# %%
import chromadb
from chromadb.utils import embedding_functions
import pandas as pd

# %%
chroma_client = chromadb.PersistentClient(path="my_chromadb")

# %%
# using the distilbert-base-nli-mean-tokens model for embedding function
sentence_transformer_ef = embedding_functions.SentenceTransformerEmbeddingFunction(model_name="distilbert-base-nli-mean-tokens")
collection = chroma_client.get_or_create_collection(name="my_collection", embedding_function=sentence_transformer_ef, metadata={"hnsw:space": "cosine"})

# %%
collection.add(
    documents=sampled_df['name'].tolist(),
    metadatas=[{"item_id": str(idx)} for idx in range(len(sampled_df))],
    ids=[str(idx) for idx in range(len(sampled_df))],
)

#note: while running this keep you laptop charging , becaz it will heatup !!!..
#hm it took me 4 minutes
# Out:
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 0
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 1
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 2
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 4
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 5
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 6
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 7
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 10
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 11
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 13
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 15
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 16
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 17
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 18
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 19
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 20
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 21
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 24
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 25
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 26
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 27
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 28
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 29
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 30
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 31
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 32
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 33
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 34
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 35
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 36
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 37
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 38
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 39
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 40
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 41
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 42
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 43
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 44
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 45
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 46
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 47
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 48
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 49
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 50
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 51
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 52
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 53
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 54
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 55
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 56
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 57
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 58
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 59
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 60
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 61
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 62
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 63
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 64
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 65
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 66
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 67
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 68
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 69
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 70
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 71
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 72
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 73
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 74
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 75
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 76
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 77
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 78
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 79
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 80
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 81
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 82
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 83
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 84
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 85
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 86
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 87
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 88
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 89
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 90
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 91
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 92
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 93
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 94
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 95
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 96
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 97
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 98
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 99
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 100
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 101
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 102
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 103
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 104
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 105
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 106
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 107
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 108
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 109
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 110
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 111
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 112
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 113
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 114
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 115
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 116
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 117
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 118
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 119
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 120
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 121
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 122
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 123
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 124
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 125
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 126
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 127
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 128
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 129
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 130
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 131
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 132
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 133
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 134
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 135
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 136
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 137
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 138
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 139
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 140
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 141
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 142
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 143
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 144
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 145
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 146
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 147
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 148
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 149
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 150
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 151
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 152
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 153
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 154
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 155
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 156
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 157
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 158
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 159
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 160
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 161
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 162
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 163
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 164
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 165
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 166
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 167
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 168
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 169
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 170
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 171
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 172
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 173
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 174
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 175
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 176
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 177
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 178
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 179
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 180
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 181
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 182
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 183
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 184
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 185
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 186
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 187
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 188
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 189
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 190
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 191
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 192
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 193
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 194
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 195
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 196
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 197
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 198
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 199
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 200
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 201
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 202
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 203
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 204
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 205
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 206
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 207
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 208
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 209
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 210
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 211
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 212
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 213
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 214
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 215
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 216
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 217
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 218
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 219
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 220
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 221
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 222
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 223
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 224
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 225
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 226
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 227
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 228
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 229
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 230
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 231
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 232
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 233
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 234
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 235
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 236
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 237
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 238
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 239
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 240
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 241
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 242
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 243
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 244
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 245
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 246
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 247
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 248
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 249
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 250
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 251
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 252
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 253
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 254
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 255
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 256
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 257
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 258
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 259
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 260
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 261
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 262
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 263
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 264
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 265
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 266
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 267
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 268
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 269
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 270
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 271
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 272
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 273
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 274
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 275
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 276
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 277
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 278
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 279
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 280
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 281
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 282
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 283
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 284
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 285
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 286
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 287
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 288
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 289
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 290
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 291
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 292
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 293
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 294
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 295
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 296
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 297
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 298
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 299
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 300
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 301
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 302
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 303
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 304
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 305
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 306
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 307
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 308
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 309
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 310
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 311
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 312
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 313
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 314
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 315
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 316
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 317
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 318
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 319
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 320
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 321
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 322
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 323
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 324
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 325
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 326
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 327
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 328
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 329
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 330
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 331
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 332
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 333
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 334
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 335
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 336
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 337
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 338
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 339
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 340
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 341
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 342
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 343
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 344
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 345
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 346
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 347
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 348
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 349
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 350
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 351
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 352
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 353
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 354
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 355
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 356
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 357
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 358
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 359
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 360
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 361
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 362
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 363
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 364
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 365
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 366
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 367
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 368
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 369
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 370
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 371
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 372
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 373
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 374
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 375
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 376
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 377
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 378
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 379
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 380
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 381
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 382
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 383
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 384
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 385
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 386
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 387
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 388
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 389
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 390
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 391
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 392
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 393
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 394
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 395
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 396
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 397
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 398
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 399
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 400
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 401
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 402
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 403
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 404
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 405
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 406
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 407
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 408
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 409
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 410
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 411
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 412
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 413
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 414
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 415
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 416
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 417
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 418
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 419
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 420
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 421
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 422
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 423
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 424
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 425
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 426
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 427
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 428
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 429
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 430
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 431
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 432
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 433
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 434
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 435
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 436
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 437
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 438
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 439
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 440
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 441
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 442
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 443
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 444
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 445
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 446
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 447
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 448
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 449
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 450
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 451
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 452
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 453
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 454
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 455
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 456
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 457
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 458
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 459
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 460
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 461
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 462
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 463
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 464
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 465
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 466
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 467
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 468
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 469
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 470
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 471
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 472
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 473
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 474
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 475
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 476
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 477
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 478
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 479
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 480
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 481
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 482
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 483
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 484
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 485
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 486
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 487
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 488
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 489
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 490
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 491
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 492
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 493
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 494
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 495
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 496
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 497
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 498
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 499
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 500
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 501
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 502
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 503
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 504
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 505
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 506
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 507
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 508
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 509
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 510
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 511
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 512
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 513
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 514
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 515
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 516
# ...
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 528
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 529
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 530
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 531
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 532
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 533
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 534
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 535
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 536
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 537
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 538
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 539
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 540
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 541
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 542
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 543
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 544
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 545
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 546
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 547
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 548
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 549
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 550
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 551
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 552
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 553
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 554
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 555
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 556
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 557
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 558
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 559
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 560
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 561
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 562
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 563
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 564
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 565
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 566
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 567
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 568
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 569
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 570
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 571
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 572
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 573
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 574
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 575
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 576
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 577
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 578
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 579
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 580
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 581
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 582
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 583
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 584
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 585
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 586
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 587
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 588
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 589
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 590
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 591
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 592
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 593
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 594
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 595
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 596
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 597
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 598
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 599
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 600
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 601
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 602
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 603
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 604
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 605
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 606
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 607
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 608
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 609
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 610
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 611
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 612
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 613
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 614
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 615
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 616
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 617
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 618
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 619
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 620
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 621
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 622
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 623
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 624
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 625
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 626
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 627
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 628
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 629
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 630
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 631
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 632
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 633
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 634
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 635
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 636
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 637
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 638
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 639
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 640
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 641
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 642
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 643
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 644
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 645
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 646
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 647
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 648
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 649
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 650
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 651
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 652
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 653
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 654
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 655
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 656
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 657
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 658
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 659
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 660
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 661
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 662
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 663
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 664
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 665
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 666
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 667
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 668
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 669
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 670
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 671
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 672
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 673
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 674
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 675
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 676
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 677
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 678
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 679
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 680
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 681
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 682
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 683
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 684
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 685
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 686
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 687
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 688
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 689
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 690
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 691
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 692
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 693
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 694
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 695
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 696
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 697
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 698
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 699
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 700
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 701
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 702
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 703
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 704
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 705
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 706
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 707
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 708
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 709
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 710
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 711
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 712
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 713
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 714
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 715
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 716
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 717
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 718
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 719

# %%
# getting user input
user_query = input("Enter your search query: ")

# querying the collection
results = collection.query(
    query_texts=[user_query],
    n_results=10,
    include=['documents', 'distances', 'metadatas']
)

# displaying the user input
print(f"Your search query: {user_query}")

# displaying output documents
for document in results['documents'][0]:
    print(f"{document}")
# Out:
# Enter your search query: why are you hurt so much
# Your search query: why are you hurt so much
#  *** down.and.dangerous.(2013).eng.1cd ***
#  *** bad.behaviour.s01.e03.exeat.(2022).eng.1cd ***
#  *** the.enemy.within.(1994).eng.1cd ***
#  *** the.enemy.within.(1994).eng.1cd ***
#  *** according.to.jim.s04.e14.a.crying.shame.(2005).eng.1cd ***
#  *** a.different.world.s04.e22.monet.is.the.root.of.all.evil.(1991).eng.1cd ***
#  *** betrayal.(1983).eng.1cd ***
#  *** victoria.s03.e07.a.public.inconvenience.(2019).eng.1cd ***
#  *** bad.behaviour.s01.e01.moth.to.a.flame.(2023).eng.1cd ***
#  *** moron.5.and.the.crying.lady.(2012).eng.1cd ***
